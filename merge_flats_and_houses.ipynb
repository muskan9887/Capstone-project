# %%
import numpy as np
import pandas as pd

# %%
flats = pd.read_csv('flats_cleaned.csv')
houses = pd.read_csv('house_cleaned.csv')

# %%
df = pd.concat([flats,houses],ignore_index=True)

# %%
df = df.sample(df.shape[0],ignore_index=True)

# %%
df.head()
# Out:
#                                       property_name property_type  \
# 0                   1 BHK Flat in Sector 49 Gurgaon          flat
# 1                   3 BHK Flat in Sector 69 Gurgaon          flat
# 2  16 Bedroom House for sale in Sushant Lok Phase 1         house
# 3    3 Bedroom House for sale in Sector 12A Gurgaon         house
# 4                  4 BHK Flat in Sector 104 Gurgaon          flat
#
#               society  price   price_per_sqft                       area  \
# 0   satya element one   0.80          11111.0                      720.0
# 1   tulip violet4.3 ?   1.31           8517.0                     1538.0
# 2         independent  13.50  ₹ 50,000/sq.ft.      (251 sq.m.) Plot Area
# 3         independent   1.70   ₹ 9,444/sq.ft.  (167 sq.m.) Built-up Area
# 4  godrej summit3.7 ?   1.75           7530.0                     2324.0
#
#                                         areaWithType      bedRoom  bathroom  \
# 0                   Built Up area: 720 (66.89 sq.m.)            1         1
# 1             Super Built up area 1538(142.88 sq.m.)            3         3
# 2                        Plot area 300(250.84 sq.m.)  16 Bedrooms        16
# 3  Built Up area: 200 (167.23 sq.m.)Carpet area: ...   3 Bedrooms         3
# 4                   Carpet area: 2324 (215.91 sq.m.)            4         5
#
#   balcony                             additionalRoom  \
# 0       1                              not available
# 1       2                                 pooja room
# 2      3+  Pooja Room,Study Room,Servant Room,Others
# 3       0                                        NaN
# 4      3+                               servant room
#
#                                              address  floorNum      facing  \
# 0  Satya Element One, Sector 49, Gurgaon, Sector ...       0.0         NaN
# 1                Sector 69 Gurgaon, Gurgaon, Haryana      12.0        East
# 2     C Block, Sushant Lok Phase 1, Gurgaon, Haryana       4.0  North-West
# 3   Prem Nagar, Sector 12A Gurgaon, Gurgaon, Haryana       1.0         NaN
# 4  A-104 First Floor Tower A, Sector 104 Gurgaon,...       1.0         NaN
#
#      agePossession                                    nearbyLocations  \
# 0        undefined  ['Standard chartered ATM', 'Icici bank ATM', '...
# 1  1 to 5 Year Old  ['Airia Mall Sector 68', 'Southern Peripheral ...
# 2  1 to 5 Year Old  ['Huda city centre metro station', 'New Life C...
# 3        undefined  ['Sheetla Mata Mandir', 'Hanuman Mandir', 'Jac...
# 4  0 to 1 Year Old  ['MG Road Metro Station', 'The Esplanade Mall'...
#
#                                          description  \
# 0  Property for sale in sector 49, gurgaon. This ...
# 1  Situated in sector 69 gurgaon, tulip violet is...
# 2  Brand new building floor wise with stilt and l...
# 3  3bhk residential house for resale in sector 12...
# 4  Godrej summit is one of the most popular desti...
#
#                                       furnishDetails  \
# 0  ['1 Wardrobe', '1 Fan', '1 Light', 'No AC', 'N...
# 1  ['3 Wardrobe', '1 Water Purifier', '5 Fan', '1...
# 2                                                NaN
# 3  ['1 Light', 'No AC', 'No Bed', 'No Chimney', '...
# 4  ['6 Fan', '5 Light', '2 AC', 'No Bed', 'No Chi...
#
#                                             features  \
# 0                                                NaN
# 1  ['Centrally Air Conditioned', 'Water purifier'...
# 2  ['Feng Shui / Vaastu Compliant', 'Private Gard...
# 3                                                NaN
# 4  ['Power Back-up', 'Intercom Facility', 'Lift(s...
#
#                                               rating
# 0  ['Safety5 out of 5', 'Lifestyle4 out of 5', 'E...
# 1  ['Green Area5 out of 5', 'Construction4 out of...
# 2  ['Environment5 out of 5', 'Lifestyle5 out of 5...
# 3  ['Environment3 out of 5', 'Lifestyle4 out of 5...
# 4  ['Green Area4.5 out of 5', 'Construction4 out ...

# %%
df.to_csv('gurgaon_properties.csv',index=False)

# %%
df.shape
# Out:
# (3961, 20)
